# %% [markdown]
# # Multilingual Compression
#
# This notebook calculates the compression stats for large multilingual tokenizers on monolingual datasets ... very slowly.
#
# It caches results to make exploration less painful.

# %%
from script_bpe.bpe.tokenizer import BPETokenizer
from script_bpe.train import tokenizer_save_path, get_pretokenizer
from script_bpe.corpus.registry import load_corpus_by_name, MONOLINGUAL_DATASETS
from collections import Counter, defaultdict
import pandas as pd
import multiprocessing
import json

# %%
PRETOKENIZERS = ["bytes_gpt4_cb", "bytes_gpt4o_cb", "scriptenc_cb", "scriptenc_gpt4o_cb"]
TRAIN_N = 256000
NUM_PROCESSES = 16
TRAIN_CORPORA = {"culturax": "CulturaX-subsample-100-bal2"}
SPLIT_VAL_CORPORA = [
    "CulturaX-subsample-100-bal2val-1",
    "CulturaX-subsample-100-bal2val-2",
    "CulturaX-subsample-100-bal2val-3",
    "CulturaX-subsample-100-bal2val-4",
]
TEST_FILES = MONOLINGUAL_DATASETS + list(TRAIN_CORPORA.values()) + SPLIT_VAL_CORPORA

# %%
for ptok in PRETOKENIZERS:  # can not nest multiprocessing, so ensure these work before
    for file in TEST_FILES:
        corpus = load_corpus_by_name(file, get_pretokenizer(ptok))

# %%
def process_file_ptok(args):
    file, ptok, tokenizer = args
    corpus = load_corpus_by_name(file, tokenizer.pretokenizer)

    lengths = []
    for atomic_tokens, count in corpus:
        text = tokenizer.pretokenizer.decode(atomic_tokens)
        tokens = tokenizer.encode(text)
        lengths.append((count, len(text), len(atomic_tokens), len(tokens)))
    total_char_len = sum(char_len * count for count, char_len, _, _ in lengths)
    total_base_len = sum(count * atomic_tok_len for count, _, atomic_tok_len, _ in lengths)
    total_tokens_len = sum(count * encoded_len for count, _, _, encoded_len in lengths)
    result = {
        "total_char_len": total_char_len,
        "total_base_len": total_base_len,
        "total_tokens_len": total_tokens_len,
    }
    return file, ptok, result


all_results = {}

for save_tag, train_corpus_name in TRAIN_CORPORA.items():
    RESULS_FILE = f"../results/{save_tag}_stats.json"
    tokenizers = {
        ptok: BPETokenizer.load(tokenizer_save_path(train_corpus_name, TRAIN_N, ptok)) for ptok in PRETOKENIZERS
    }

    # Load existing stats
    try:
        with open(RESULS_FILE, "r") as f:
            length_stats = json.load(f)
    except FileNotFoundError:
        length_stats = {}

    # Create processing tasks (filtering out already computed)
    tasks = [
        (file, ptok, tokenizers[ptok])
        for file in TEST_FILES
        for ptok in PRETOKENIZERS
        if ptok in tokenizers and ptok not in length_stats.get(file, {})
    ]

    print(
        f"Processing {len(tasks)} remaining tasks of out {len(TEST_FILES) * len(PRETOKENIZERS)} for {train_corpus_name}..."
    )

    with multiprocessing.Pool(NUM_PROCESSES) as pool:
        for file, ptok, stats in pool.imap_unordered(process_file_ptok, tasks):
            print(f"Completed {save_tag}  {ptok:<25} on {file:<15}: {stats}")
            length_stats.setdefault(file, {})
            length_stats[file][ptok] = stats
            with open(RESULS_FILE, "w") as f:  # Save after each result
                json.dump(length_stats, f, indent=2)
    all_results[save_tag] = length_stats
# Out:
# Processing 0 remaining tasks of out 68 for CulturaX-subsample-100-bal2...

# %%
merged_val_tag = "CulturaX (validation merged)"

for save_tag, length_stats in all_results.items():
    combined_results = defaultdict(Counter)
    for train_set, stats_by_pretok in length_stats.items():
        if train_set not in SPLIT_VAL_CORPORA:
            continue
        for pretok, stats in stats_by_pretok.items():
            for k, v in stats.items():
                combined_results[pretok][k] += v
    length_stats[merged_val_tag] = combined_results

if merged_val_tag not in TEST_FILES:
    TEST_FILES.append(merged_val_tag)

# %%
pretokenizers_to_vis = PRETOKENIZERS  # also ensures order

for save_tag, length_stats in all_results.items():
    df = pd.DataFrame.from_dict(length_stats, orient="index").map(
        lambda d: (d["total_tokens_len"] / d["total_char_len"])
    )
    df = df.loc[TEST_FILES, [c for c in pretokenizers_to_vis if c in df.columns]]  # order consistenly
    df.loc["mean monolingual"] = df.iloc[:12].mean()
    rel_val = df.div(df.median(axis=1), axis=0)
    display(
        df.style.highlight_min(axis=1, props="font-weight:bold; text-decoration:underline;")
        .background_gradient(cmap="RdYlGn_r", gmap=rel_val, axis=None, vmin=0.9, vmax=1.1)
        .set_caption(f"Table 4: Compression ratios (#tokens/char) for {save_tag}")
        .format("{:.4f}")
    )
# Out:
# <style type="text/css">
# #T_b6ed2_row0_col0, #T_b6ed2_row1_col1, #T_b6ed2_row2_col1, #T_b6ed2_row2_col3, #T_b6ed2_row3_col3, #T_b6ed2_row4_col1, #T_b6ed2_row5_col1, #T_b6ed2_row5_col2, #T_b6ed2_row6_col3, #T_b6ed2_row7_col1, #T_b6ed2_row9_col1, #T_b6ed2_row10_col1, #T_b6ed2_row11_col1 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_b6ed2_row0_col1, #T_b6ed2_row1_col3, #T_b6ed2_row2_col0, #T_b6ed2_row3_col2, #T_b6ed2_row4_col3, #T_b6ed2_row5_col3, #T_b6ed2_row6_col2, #T_b6ed2_row7_col3, #T_b6ed2_row9_col3, #T_b6ed2_row10_col3, #T_b6ed2_row11_col3 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_b6ed2_row0_col2 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_b6ed2_row0_col3 {
#   font-weight: bold;
#   text-decoration: underline;
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_b6ed2_row1_col0, #T_b6ed2_row6_col0 {
#   font-weight: bold;
#   text-decoration: underline;
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_b6ed2_row1_col2, #T_b6ed2_row16_col0 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_b6ed2_row2_col2 {
#   font-weight: bold;
#   text-decoration: underline;
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_b6ed2_row3_col0, #T_b6ed2_row10_col0, #T_b6ed2_row11_col2, #T_b6ed2_row14_col3, #T_b6ed2_row15_col3, #T_b6ed2_row16_col3, #T_b6ed2_row17_col3 {
#   font-weight: bold;
#   text-decoration: underline;
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_b6ed2_row3_col1, #T_b6ed2_row4_col0, #T_b6ed2_row6_col1 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_b6ed2_row4_col2, #T_b6ed2_row7_col2, #T_b6ed2_row12_col3, #T_b6ed2_row13_col3 {
#   font-weight: bold;
#   text-decoration: underline;
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_b6ed2_row5_col0, #T_b6ed2_row9_col0 {
#   font-weight: bold;
#   text-decoration: underline;
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_b6ed2_row7_col0, #T_b6ed2_row8_col0, #T_b6ed2_row11_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_b6ed2_row8_col1 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_b6ed2_row8_col2 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_b6ed2_row8_col3 {
#   font-weight: bold;
#   text-decoration: underline;
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_b6ed2_row9_col2 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_b6ed2_row10_col2 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_b6ed2_row12_col0, #T_b6ed2_row13_col0 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_b6ed2_row12_col1, #T_b6ed2_row13_col1 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_b6ed2_row12_col2 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_b6ed2_row13_col2 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_b6ed2_row14_col0, #T_b6ed2_row15_col0, #T_b6ed2_row17_col0 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_b6ed2_row14_col1, #T_b6ed2_row15_col1, #T_b6ed2_row17_col1 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_b6ed2_row14_col2, #T_b6ed2_row15_col2, #T_b6ed2_row17_col2 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_b6ed2_row16_col1 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_b6ed2_row16_col2 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_b6ed2_row18_col0 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_b6ed2_row18_col1 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_b6ed2_row18_col2 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_b6ed2_row18_col3 {
#   font-weight: bold;
#   text-decoration: underline;
#   background-color: #f2faae;
#   color: #000000;
# }
# </style>
# <table id="T_b6ed2">
#   <caption>Table 4: Compression ratios (#tokens/char) for culturax</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6ed2_level0_col0" class="col_heading level0 col0" >bytes_gpt4_cb</th>
#       <th id="T_b6ed2_level0_col1" class="col_heading level0 col1" >bytes_gpt4o_cb</th>
#       <th id="T_b6ed2_level0_col2" class="col_heading level0 col2" >scriptenc_cb</th>
#       <th id="T_b6ed2_level0_col3" class="col_heading level0 col3" >scriptenc_gpt4o_cb</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6ed2_level0_row0" class="row_heading level0 row0" >eng_latn_300mb</th>
#       <td id="T_b6ed2_row0_col0" class="data row0 col0" >0.2152</td>
#       <td id="T_b6ed2_row0_col1" class="data row0 col1" >0.2150</td>
#       <td id="T_b6ed2_row0_col2" class="data row0 col2" >0.2179</td>
#       <td id="T_b6ed2_row0_col3" class="data row0 col3" >0.2150</td>
#     </tr>
#     <tr>
#       <th id="T_b6ed2_level0_row1" class="row_heading level0 row1" >deu_latn_300mb</th>
#       <td id="T_b6ed2_row1_col0" class="data row1 col0" >0.2128</td>
#       <td id="T_b6ed2_row1_col1" class="data row1 col1" >0.2133</td>
#       <td id="T_b6ed2_row1_col2" class="data row1 col2" >0.2138</td>
#       <td id="T_b6ed2_row1_col3" class="data row1 col3" >0.2132</td>
#     </tr>
#     <tr>
#       <th id="T_b6ed2_level0_row2" class="row_heading level0 row2" >vie_latn_300mb</th>
#       <td id="T_b6ed2_row2_col0" class="data row2 col0" >0.2688</td>
#       <td id="T_b6ed2_row2_col1" class="data row2 col1" >0.2692</td>
#       <td id="T_b6ed2_row2_col2" class="data row2 col2" >0.2687</td>
#       <td id="T_b6ed2_row2_col3" class="data row2 col3" >0.2692</td>
#     </tr>
#     <tr>
#       <th id="T_b6ed2_level0_row3" class="row_heading level0 row3" >heb_hebr_300mb</th>
#       <td id="T_b6ed2_row3_col0" class="data row3 col0" >0.4146</td>
#       <td id="T_b6ed2_row3_col1" class="data row3 col1" >0.4163</td>
#       <td id="T_b6ed2_row3_col2" class="data row3 col2" >0.4157</td>
#       <td id="T_b6ed2_row3_col3" class="data row3 col3" >0.4161</td>
#     </tr>
#     <tr>
#       <th id="T_b6ed2_level0_row4" class="row_heading level0 row4" >arb_arab_300mb</th>
#       <td id="T_b6ed2_row4_col0" class="data row4 col0" >0.2979</td>
#       <td id="T_b6ed2_row4_col1" class="data row4 col1" >0.2976</td>
#       <td id="T_b6ed2_row4_col2" class="data row4 col2" >0.2963</td>
#       <td id="T_b6ed2_row4_col3" class="data row4 col3" >0.2975</td>
#     </tr>
#     <tr>
#       <th id="T_b6ed2_level0_row5" class="row_heading level0 row5" >rus_cyrl_300mb</th>
#       <td id="T_b6ed2_row5_col0" class="data row5 col0" >0.2314</td>
#       <td id="T_b6ed2_row5_col1" class="data row5 col1" >0.2321</td>
#       <td id="T_b6ed2_row5_col2" class="data row5 col2" >0.2321</td>
#       <td id="T_b6ed2_row5_col3" class="data row5 col3" >0.2320</td>
#     </tr>
#     <tr>
#       <th id="T_b6ed2_level0_row6" class="row_heading level0 row6" >kor_hang_300mb</th>
#       <td id="T_b6ed2_row6_col0" class="data row6 col0" >0.5808</td>
#       <td id="T_b6ed2_row6_col1" class="data row6 col1" >0.5827</td>
#       <td id="T_b6ed2_row6_col2" class="data row6 col2" >0.5817</td>
#       <td id="T_b6ed2_row6_col3" class="data row6 col3" >0.5824</td>
#     </tr>
#     <tr>
#       <th id="T_b6ed2_level0_row7" class="row_heading level0 row7" >hin_deva_300mb</th>
#       <td id="T_b6ed2_row7_col0" class="data row7 col0" >0.5057</td>
#       <td id="T_b6ed2_row7_col1" class="data row7 col1" >0.3246</td>
#       <td id="T_b6ed2_row7_col2" class="data row7 col2" >0.3233</td>
#       <td id="T_b6ed2_row7_col3" class="data row7 col3" >0.3245</td>
#     </tr>
#     <tr>
#       <th id="T_b6ed2_level0_row8" class="row_heading level0 row8" >tha_thai_300mb</th>
#       <td id="T_b6ed2_row8_col0" class="data row8 col0" >0.4257</td>
#       <td id="T_b6ed2_row8_col1" class="data row8 col1" >0.3160</td>
#       <td id="T_b6ed2_row8_col2" class="data row8 col2" >0.3362</td>
#       <td id="T_b6ed2_row8_col3" class="data row8 col3" >0.3159</td>
#     </tr>
#     <tr>
#       <th id="T_b6ed2_level0_row9" class="row_heading level0 row9" >zho_hans_300mb</th>
#       <td id="T_b6ed2_row9_col0" class="data row9 col0" >0.6244</td>
#       <td id="T_b6ed2_row9_col1" class="data row9 col1" >0.6260</td>
#       <td id="T_b6ed2_row9_col2" class="data row9 col2" >0.6537</td>
#       <td id="T_b6ed2_row9_col3" class="data row9 col3" >0.6259</td>
#     </tr>
#     <tr>
#       <th id="T_b6ed2_level0_row10" class="row_heading level0 row10" >jpn_jpan_300mb</th>
#       <td id="T_b6ed2_row10_c
